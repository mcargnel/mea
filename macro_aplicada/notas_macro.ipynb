# %% [markdown]
# - Nos interesan las fluctuaciones de la economía
# - la tendencia de crecimiento es una variable no observable, se asume que en el largo plazo crece, puede cambiar a lo largo del tiempo
# - se busca una macro con poca volatilidad y acercar el ciclo a la tendencia
# - el gasto y el producto se mueven de forma acíclica
